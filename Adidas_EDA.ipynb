# %% [markdown]
# # Adidas Sales Analysis

# %% [markdown]
# ### Importing Important Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading Data from csv file

# %%
data = pd.read_csv("adidas_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     Retailer  Retailer ID         Invoice Date     Region  \
# 0           0  Foot Locker      1185732  2020-01-01 00:00:00  Northeast
# 1           1  Foot Locker      1185732  2020-01-02 00:00:00  Northeast
# 2           2  Foot Locker      1185732  2020-01-03 00:00:00  Northeast
# 3           3  Foot Locker      1185732  2020-01-04 00:00:00  Northeast
# 4           4  Foot Locker      1185732  2020-01-05 00:00:00  Northeast
#
#       State      City                    Product  Price per Unit  Units Sold  \
# 0  New York  New York      Men's Street Footwear            50.0        1200
# 1  New York  New York    Men's Athletic Footwear            50.0        1000
# 2  New York  New York    Women's Street Footwear            40.0        1000
# 3  New York  New York  Women's Athletic Footwear            45.0         850
# 4  New York  New York              Men's Apparel            60.0         900
#
#    Total Sales  Operating Profit  Operating Margin Sales Method
# 0     600000.0          300000.0              0.50     In-store
# 1     500000.0          150000.0              0.30     In-store
# 2     400000.0          140000.0              0.35     In-store
# 3     382500.0          133875.0              0.35     In-store
# 4     540000.0          162000.0              0.30     In-store

# %%
data.tail()
# Out:
#       Unnamed: 0     Retailer  Retailer ID         Invoice Date     Region  \
# 9643        9643  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9644        9644  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9645        9645  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9646        9646  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9647        9647  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
#
#               State        City                  Product  Price per Unit  \
# 9643  New Hampshire  Manchester            Men's Apparel            50.0
# 9644  New Hampshire  Manchester          Women's Apparel            41.0
# 9645  New Hampshire  Manchester    Men's Street Footwear            41.0
# 9646  New Hampshire  Manchester  Men's Athletic Footwear            42.0
# 9647  New Hampshire  Manchester  Women's Street Footwear            29.0
#
#       Units Sold  Total Sales  Operating Profit  Operating Margin Sales Method
# 9643          64       3200.0            896.00              0.28       Outlet
# 9644         105       4305.0           1377.60              0.32       Outlet
# 9645         184       7544.0           2791.28              0.37       Outlet
# 9646          70       2940.0           1234.80              0.42       Outlet
# 9647          83       2407.0            649.89              0.27       Outlet

# %%
data.sample(10)
# Out:
#       Unnamed: 0       Retailer  Retailer ID         Invoice Date     Region  \
# 9227        9227      West Gear      1197831  2021-04-20 00:00:00      South
# 4520        4520      West Gear      1128299  2020-05-14 00:00:00       West
# 7739        7739         Amazon      1185732  2021-08-18 00:00:00  Northeast
# 1512        1512         Kohl's      1185732  2021-02-12 00:00:00       West
# 2572        2572         Amazon      1185732  2021-11-22 00:00:00  Southeast
# 4670        4670  Sports Direct      1185732  2020-05-24 00:00:00  Southeast
# 4481        4481      West Gear      1128299  2020-04-05 00:00:00       West
# 2213        2213         Kohl's      1128299  2021-11-26 00:00:00       West
# 3816        3816         Amazon      1185732  2021-02-19 00:00:00  Northeast
# 6170        6170  Sports Direct      1128299  2021-10-13 00:00:00  Southeast
#
#               State           City                    Product  Price per Unit  \
# 9227       Oklahoma  Oklahoma City    Women's Street Footwear            10.0
# 4520       Colorado         Denver      Men's Street Footwear            52.0
# 7739  New Hampshire     Manchester    Women's Street Footwear            52.0
# 1512        Wyoming       Cheyenne  Women's Athletic Footwear            35.0
# 2572       Kentucky     Louisville    Men's Athletic Footwear            40.0
# 4670        Florida          Miami      Men's Street Footwear            63.0
# 4481       Colorado         Denver  Women's Athletic Footwear            56.0
# 2213     New Mexico    Albuquerque    Women's Street Footwear            60.0
# 3816  New Hampshire     Manchester  Women's Athletic Footwear            45.0
# 6170        Georgia        Atlanta            Women's Apparel            64.0
#
#       Units Sold  Total Sales  Operating Profit  Operating Margin Sales Method
# 9227          70        700.0            322.00              0.46       Outlet
# 4520         150       7800.0           4290.00              0.55       Online
# 7739         105       5460.0           2457.00              0.45       Online
# 1512         425     148750.0          52062.50              0.35     In-store
# 2572         275     110000.0          38500.00              0.35       Online
# 4670         323      20349.0          11395.44              0.56       Online
# 4481          74       4144.0           1781.92              0.43       Online
# 2213         450     270000.0          94500.00              0.35       Online
# 3816         200      90000.0          27000.00              0.30     In-store
# 6170         102       6528.0           2545.92              0.39       Online

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Retailer', 'Retailer ID', 'Invoice Date', 'Region',
#        'State', 'City', 'Product', 'Price per Unit', 'Units Sold',
#        'Total Sales', 'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
data.shape
# Out:
# (9648, 14)

# %%
data.size
# Out:
# 135072

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        9648 non-null   int64
#  1   Retailer          9648 non-null   object
#  2   Retailer ID       9648 non-null   int64
#  3   Invoice Date      9648 non-null   object
#  4   Region            9648 non-null   object
#  5   State             9648 non-null   object
#  6   City              9648 non-null   object
#  7   Product           9648 non-null   object
#  8   Price per Unit    9648 non-null   float64
#  9   Units Sold        9648 non-null   int64
#  10  Total Sales       9648 non-null   float64
#  11  Operating Profit  9648 non-null   float64
#  12  Operating Margin  9648 non-null   float64
#  13  Sales Method      9648 non-null   object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 1.0+ MB

# %%
data['Invoice Date'] = pd.to_datetime(data['Invoice Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        9648 non-null   int64
#  1   Retailer          9648 non-null   object
#  2   Retailer ID       9648 non-null   int64
#  3   Invoice Date      9648 non-null   datetime64[ns]
#  4   Region            9648 non-null   object
#  5   State             9648 non-null   object
#  6   City              9648 non-null   object
#  7   Product           9648 non-null   object
#  8   Price per Unit    9648 non-null   float64
#  9   Units Sold        9648 non-null   int64
#  10  Total Sales       9648 non-null   float64
#  11  Operating Profit  9648 non-null   float64
#  12  Operating Margin  9648 non-null   float64
#  13  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(6)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#         Unnamed: 0   Retailer ID                   Invoice Date  \
# count  9648.000000  9.648000e+03                           9648
# mean   4823.500000  1.173850e+06  2021-05-10 15:20:44.776119296
# min       0.000000  1.128299e+06            2020-01-01 00:00:00
# 25%    2411.750000  1.185732e+06            2021-02-17 00:00:00
# 50%    4823.500000  1.185732e+06            2021-06-04 00:00:00
# 75%    7235.250000  1.185732e+06            2021-09-16 00:00:00
# max    9647.000000  1.197831e+06            2021-12-31 00:00:00
# std    2785.282032  2.636038e+04                            NaN
#
#        Price per Unit   Units Sold    Total Sales  Operating Profit  \
# count     9648.000000  9648.000000    9648.000000       9648.000000
# mean        45.216625   256.930037   93273.437500      34425.244761
# min          7.000000     0.000000       0.000000          0.000000
# 25%         35.000000   106.000000    4254.500000       1921.752500
# 50%         45.000000   176.000000    9576.000000       4371.420000
# 75%         55.000000   350.000000  150000.000000      52062.500000
# max        110.000000  1275.000000  825000.000000     390000.000000
# std         14.705397   214.252030  141916.016727      54193.113713
#
#        Operating Margin
# count       9648.000000
# mean           0.422991
# min            0.100000
# 25%            0.350000
# 50%            0.410000
# 75%            0.490000
# max            0.800000
# std            0.097197

# %%
print("Numbers of Retailer: ",len(data['Retailer'].unique()))
print("Name of Retailers: ",data.Retailer.unique())
# Out:
# Numbers of Retailer:  6
# Name of Retailers:  ['Foot Locker' 'Walmart' 'Sports Direct' 'West Gear' "Kohl's" 'Amazon']

# %%
print("Number of Products: ",len(data['Product'].unique()))
print("Name of Products: ",data.Product.unique())
# Out:
# Number of Products:  6
# Name of Products:  ["Men's Street Footwear" "Men's Athletic Footwear"
#  "Women's Street Footwear" "Women's Athletic Footwear" "Men's Apparel"
#  "Women's Apparel"]

# %%
print("Number of Sales Methods: ",len(data['Sales Method'].unique()))
print("Sales Method: ",data['Sales Method'].unique())
# Out:
# Number of Sales Methods:  3
# Sales Method:  ['In-store' 'Outlet' 'Online']

# %%
data['Retailer'].value_counts()
# Out:
# Retailer
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: count, dtype: int64

# %%
sns.boxplot(data['Retailer'].value_counts().values)
# Out:
# <Axes: >

# %%
print("Min Date Present is:",data["Invoice Date"].min())
print("Max Date Present is:",data["Invoice Date"].max())
print("Total Duration of data is:",data["Invoice Date"].max() - data["Invoice Date"].min())
# Out:
# Min Date Present is: 2020-01-01 00:00:00
# Max Date Present is: 2021-12-31 00:00:00
# Total Duration of data is: 730 days 00:00:00

# %%
data.City.unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester'], dtype=object)

# %%
data['Sales Method'].value_counts()
# Out:
# Sales Method
# Online      4889
# Outlet      3019
# In-store    1740
# Name: count, dtype: int64

# %% [markdown]
# ### Duplicate and Null values checking

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Unnamed: 0          0
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %% [markdown]
# ### Check the numeric data correctness

# %%
data['Calculated Total sales'] = data['Price per Unit'] * data['Units Sold']

# %%
data['Calculated Operating Profit'] = data['Calculated Total sales'] * data['Operating Margin']

# %%
incorrect_total_sales = (~data['Calculated Total sales'].eq(data['Total Sales'])).sum()

# %%
incorrect_operating_profit = (~data['Calculated Operating Profit'].eq(data['Operating Profit'])).sum()

# %%
incorrect_total_sales, incorrect_operating_profit
# Out:
# (np.int64(3886), np.int64(5408))

# %%
data['Total Sales'] = data['Calculated Total sales']
data['Operating Profit'] = data['Calculated Operating Profit']
data = data.drop(columns=['Calculated Total sales','Calculated Operating Profit'],axis=1)

# %%
data['Week Day'] = data['Invoice Date'].dt.day_name()
data['Month'] = data['Invoice Date'].dt.strftime("%B")
data['Year'] = data['Invoice Date'].dt.year

# %%
data['Season'] = data['Month'].apply(lambda x: 'Winter' if(x in [1,2,12]) else
                                     'Spring' if(x in [3,4,5])else
                                     'Summer' if(x in [6,7,8])else
                                     'Autumn')
data['Month year'] = data['Invoice Date'].dt.to_period('M').astype('datetime64[ns]')

# %%
data[['Type','Group']] = data['Product'].str.extract(r"(Men's|Women's)\s(.*)")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        9648 non-null   int64
#  1   Retailer          9648 non-null   object
#  2   Retailer ID       9648 non-null   int64
#  3   Invoice Date      9648 non-null   datetime64[ns]
#  4   Region            9648 non-null   object
#  5   State             9648 non-null   object
#  6   City              9648 non-null   object
#  7   Product           9648 non-null   object
#  8   Price per Unit    9648 non-null   float64
#  9   Units Sold        9648 non-null   int64
#  10  Total Sales       9648 non-null   float64
#  11  Operating Profit  9648 non-null   float64
#  12  Operating Margin  9648 non-null   float64
#  13  Sales Method      9648 non-null   object
#  14  Week Day          9648 non-null   object
#  15  Month             9648 non-null   object
#  16  Year              9648 non-null   int32
#  17  Season            9648 non-null   object
#  18  Month year        9648 non-null   datetime64[ns]
#  19  Type              9648 non-null   object
#  20  Group             9648 non-null   object
# dtypes: datetime64[ns](2), float64(4), int32(1), int64(3), object(11)
# memory usage: 1.5+ MB

# %%
data.head()
# Out:
#    Unnamed: 0     Retailer  Retailer ID Invoice Date     Region     State  \
# 0           0  Foot Locker      1185732   2020-01-01  Northeast  New York
# 1           1  Foot Locker      1185732   2020-01-02  Northeast  New York
# 2           2  Foot Locker      1185732   2020-01-03  Northeast  New York
# 3           3  Foot Locker      1185732   2020-01-04  Northeast  New York
# 4           4  Foot Locker      1185732   2020-01-05  Northeast  New York
#
#        City                    Product  Price per Unit  Units Sold  ...  \
# 0  New York      Men's Street Footwear            50.0        1200  ...
# 1  New York    Men's Athletic Footwear            50.0        1000  ...
# 2  New York    Women's Street Footwear            40.0        1000  ...
# 3  New York  Women's Athletic Footwear            45.0         850  ...
# 4  New York              Men's Apparel            60.0         900  ...
#
#    Operating Profit  Operating Margin  Sales Method   Week Day    Month  Year  \
# 0           30000.0              0.50      In-store  Wednesday  January  2020
# 1           15000.0              0.30      In-store   Thursday  January  2020
# 2           14000.0              0.35      In-store     Friday  January  2020
# 3           13387.5              0.35      In-store   Saturday  January  2020
# 4           16200.0              0.30      In-store     Sunday  January  2020
#
#    Season Month year     Type              Group
# 0  Autumn 2020-01-01    Men's    Street Footwear
# 1  Autumn 2020-01-01    Men's  Athletic Footwear
# 2  Autumn 2020-01-01  Women's    Street Footwear
# 3  Autumn 2020-01-01  Women's  Athletic Footwear
# 4  Autumn 2020-01-01    Men's            Apparel
#
# [5 rows x 21 columns]

# %%
data['Region'].value_counts()
# Out:
# Region
# West         2448
# Northeast    2376
# Midwest      1872
# South        1728
# Southeast    1224
# Name: count, dtype: int64

# %%
sns.boxplot(data["Region"].value_counts().values)
# Out:
# <Axes: >

# %%
data["State"].value_counts()
# Out:
# State
# Texas             432
# California        432
# New York          360
# Florida           360
# Nevada            216
# Pennsylvania      216
# Alabama           216
# Tennessee         216
# Arkansas          216
# Mississippi       216
# New Mexico        216
# Georgia           216
# Arizona           216
# Idaho             216
# Oregon            216
# Louisiana         216
# Utah              216
# Virginia          216
# New Hampshire     216
# Vermont           216
# Connecticut       216
# Rhode Island      216
# Massachusetts     216
# Oklahoma          216
# Wyoming           144
# Hawaii            144
# Colorado          144
# Illinois          144
# Alaska            144
# Maine             144
# Nebraska          144
# Montana           144
# Washington        144
# Minnesota         144
# Ohio              144
# Kentucky          144
# South Carolina    144
# North Carolina    144
# Missouri          144
# Michigan          144
# South Dakota      144
# Kansas            144
# West Virginia     144
# Indiana           144
# Wisconsin         144
# Iowa              144
# North Dakota      144
# New Jersey        144
# Maryland          144
# Delaware          144
# Name: count, dtype: int64

# %%
sns.boxplot(data["State"].value_counts().values)
# Out:
# <Axes: >

# %%
data['Product'].value_counts()
# Out:
# Product
# Men's Street Footwear        1610
# Men's Athletic Footwear      1610
# Women's Street Footwear      1608
# Women's Apparel              1608
# Women's Athletic Footwear    1606
# Men's Apparel                1606
# Name: count, dtype: int64

# %%
sns.histplot(data["Price per Unit"],kde=True)
# Out:
# <Axes: xlabel='Price per Unit', ylabel='Count'>

# %%
sns.histplot(data["Units Sold"],kde=True)
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %% [markdown]
# ### Top Selling Products

# %%
top_selling_products = data.groupby('Product')['Total Sales'].sum().sort_values(ascending=False).reset_index()
top_selling_products
# Out:
#                      Product  Total Sales
# 0      Men's Street Footwear   27680769.0
# 1            Women's Apparel   23870985.0
# 2    Men's Athletic Footwear   20577180.0
# 3    Women's Street Footwear   17201563.0
# 4              Men's Apparel   16520632.0
# 5  Women's Athletic Footwear   14315521.0

# %%
sns.barplot(data = top_selling_products, x='Total Sales', y='Product', palette='viridis')
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\3575578457.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_selling_products, x='Total Sales', y='Product', palette='viridis')
# <Axes: xlabel='Total Sales', ylabel='Product'>

# %% [markdown]
# ### Cities with their operating cost

# %%
grossing_cities = data.groupby('City')['Operating Profit'].sum().sort_values(ascending=False).reset_index()
grossing_cities.index+=1

# %%
grossing_cities
# Out:
#               City  Operating Profit
# 1         New York        2114664.41
# 2       Charleston        2024086.36
# 3    San Francisco        1581993.31
# 4            Miami        1579387.86
# 5         Portland        1575860.62
# 6          Houston        1494772.31
# 7      New Orleans        1424389.74
# 8      Los Angeles        1378158.34
# 9       Birmingham        1368206.39
# 10         Orlando        1342206.56
# 11          Dallas        1337738.29
# 12       Knoxville        1269585.06
# 13       Charlotte        1263674.12
# 14           Boise        1222558.85
# 15          Albany        1220894.66
# 16        Richmond        1174799.43
# 17       Las Vegas        1084651.92
# 18         Detroit        1050351.52
# 19         Atlanta        1049533.36
# 20     Albuquerque        1027672.91
# 21          Denver        1000512.08
# 22        Columbus         973251.34
# 23         Jackson         959892.23
# 24         Seattle         927709.38
# 25      Manchester         881847.68
# 26      Burlington         875093.99
# 27        Cheyenne         856048.65
# 28         Phoenix         819408.33
# 29        Billings         810775.05
# 30        Honolulu         779756.57
# 31     Little Rock         746290.41
# 32        Hartford         632060.79
# 33    Philadelphia         630100.50
# 34   Oklahoma City         620730.89
# 35       Anchorage         592154.61
# 36  Salt Lake City         588845.35
# 37      Wilmington         588323.81
# 38          Boston         517402.12
# 39      Louisville         514300.23
# 40         Chicago         508648.61
# 41       St. Louis         506446.86
# 42          Newark         476907.22
# 43      Providence         463312.26
# 44         Wichita         460373.54
# 45    Indianapolis         439574.75
# 46     Sioux Falls         383144.46
# 47       Milwaukee         365126.34
# 48       Baltimore         359490.87
# 49           Fargo         352558.47
# 50     Minneapolis         347262.26
# 51      Des Moines         345626.12
# 52           Omaha         316805.91

# %% [markdown]
# ### Top Cities with their operating cost

# %%
sns.barplot(data=grossing_cities.head(10),y='City',x='Operating Profit',palette='magma')
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\2555046732.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=grossing_cities.head(10),y='City',x='Operating Profit',palette='magma')
# <Axes: xlabel='Operating Profit', ylabel='City'>

# %% [markdown]
# ### Top Retailers

# %%
top_retailers = data.groupby('Retailer')['Total Sales'].sum().sort_values(ascending=False).reset_index()
top_retailers
# Out:
#         Retailer  Total Sales
# 0      West Gear   32409558.0
# 1    Foot Locker   29024945.0
# 2  Sports Direct   24616622.0
# 3         Kohl's   13512453.0
# 4        Walmart   10506085.0
# 5         Amazon   10096987.0

# %%
sns.barplot(data=top_retailers,x='Total Sales', y='Retailer',palette='plasma')
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\3708354484.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_retailers,x='Total Sales', y='Retailer',palette='plasma')
# <Axes: xlabel='Total Sales', ylabel='Retailer'>

# %% [markdown]
# - Region

# %% [markdown]
# ### Percentage of Retailers in Diff Region

# %%
retailer_region = data.groupby('Region')['Retailer ID'].count()
retailer_region
# Out:
# Region
# Midwest      1872
# Northeast    2376
# South        1728
# Southeast    1224
# West         2448
# Name: Retailer ID, dtype: int64

# %%
plt.pie(retailer_region, labels=retailer_region.index, autopct=lambda pct : f'{pct:.1f}%\n({int(pct/100*retailer_region.sum())})')
plt.title("Amount of Retailers in Different Region")
plt.show()

# %% [markdown]
# ### Percentage of sales in diff region

# %%
region_sales = data.groupby('Region')['Total Sales'].sum()
region_sales
# Out:
# Region
# Midwest      16674434.0
# Northeast    25078267.0
# South        20603356.0
# Southeast    21374436.0
# West         36436157.0
# Name: Total Sales, dtype: float64

# %%
plt.pie(region_sales,labels = region_sales.index, autopct='%1.1f%%')
plt.title("Percentage of Sales in different region")
plt.show()

# %% [markdown]
# ### Region wise Total Sales

# %%
adidas = data.groupby('Region')['Total Sales'].sum().divide(data.groupby('Region')['Retailer ID'].count())

plt.bar(adidas.index, adidas.values)

for i, value in enumerate(adidas.values):
    plt.text(i, value, str(round(value, 2)), ha='center', va='bottom')

plt.xticks(rotation=45)

plt.title("Total Sales per Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()
print(adidas)
# Out:
# Region
# Midwest       8907.283120
# Northeast    10554.826178
# South        11923.238426
# Southeast    17462.774510
# West         14884.051062
# dtype: float64

# %% [markdown]
# ### Region wise Total Sales

# %%
adidas_southeast = data.pivot_table(values='Total Sales', index='Month', columns='Region', fill_value=0)

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

adidas_southeast = adidas_southeast.reindex(month_order)

adidas_southeast.plot.line()
plt.xticks(range(len(adidas_southeast.index)), adidas_southeast.index)


plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Month')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Total Sales in Southeast region

# %%
adidas_states = data.pivot_table(values='Total Sales', index=['Region','State'],columns='Month',fill_value=0)
regions = 'Southeast'

months = ['June', 'July', 'August', 'November', 'December']
Southeast_data = adidas_states.loc[regions,months].round(2)
Southeast_data.plot.bar()
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Sales at Southeast Region')
plt.xticks(rotation=45)
Southeast_data
# Out:
# Month               June      July    August  November  December
# State
# Florida         28175.06  33824.00  23750.15  19264.67  27519.17
# Georgia         13789.94  14806.06  15470.06  13628.61  15732.22
# Kentucky         7718.92  10654.50  10433.17   8827.92  12039.00
# North Carolina  25457.17  31595.50  28471.92  23482.67  31677.58
# South Carolina  29969.33  35572.42  32238.33  28394.83  35799.75
# Virginia        23971.72  29899.50  21455.06  14846.78  22506.28

# %% [markdown]
# ### Total Sales per Retailers

# %%
adidas_invest = data.groupby('Retailer')['Total Sales'].sum().sort_values()
adidas_invest_million = adidas_invest/1000

plt.figure(figsize=(10,6))
plt.bar(adidas_invest.index, adidas_invest_million.values)

for i, value in enumerate(adidas_invest_million.values):
    plt.text(i, value, str(round(value, 2)), ha='center', va='bottom')

plt.title('Total Sales per Retailer')
plt.xlabel('Retailer')
plt.ylabel('Total Sales (Milions$)')

plt.show()

# %% [markdown]
# ### Sales over Year '2020' and '2021'

# %%
adidas_2020 = data[data['Year']==2020]
adidas_retailer_2020 = pd.pivot_table(adidas_2020,values='Total Sales',index=['Month'],columns='Retailer', aggfunc=np.sum,fill_value=0)
adidas_retailer_Thousands_2020 = (adidas_retailer_2020/1000).round(2)
adidas_retailer_Thousands_2020 = adidas_retailer_Thousands_2020.reindex(month_order)


adidas_2021 = data[data['Year']==2021]
adidas_retailer_2021 = pd.pivot_table(adidas_2021,values='Total Sales',index=['Month'],columns='Retailer', aggfunc=np.sum,fill_value=0)
adidas_retailer_Thousands_2021 = (adidas_retailer_2021/1000).round(2)
adidas_retailer_Thousands_2021 = adidas_retailer_Thousands_2021.reindex(month_order)

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].plot(adidas_retailer_Thousands_2020.index, adidas_retailer_Thousands_2020[['Walmart','Sports Direct','Foot Locker','West Gear']], 
             label=['Walmart','Sports Direct','Foot Locker','West Gear'])
axes[0].plot(adidas_retailer_Thousands_2020.index, adidas_retailer_Thousands_2020["Kohl's"], label="Kohl's")
# Add more lines for other retailers as needed
axes[0].set_title('Total Sales in 2020')
axes[0].set_xlabel('Month')
axes[0].set_ylabel('Sales (Thousands)')
axes[0].legend()

axes[1].plot(adidas_retailer_Thousands_2021.index, adidas_retailer_Thousands_2021[['Amazon','Walmart','Sports Direct','Foot Locker','West Gear']], 
             label=['Amazon','Walmart','Sport Direct','Foot Locker','West Gear'])
axes[1].plot(adidas_retailer_Thousands_2021.index, adidas_retailer_Thousands_2021["Kohl's"], label="Kohl's")
# Add more lines for other retailers as needed
axes[1].set_title('Total Sales in 2021')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Sales (Thousands)')
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\2725120943.py:2: FutureWarning: The provided callable <function sum at 0x0000021E7708A160> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   adidas_retailer_2020 = pd.pivot_table(adidas_2020,values='Total Sales',index=['Month'],columns='Retailer', aggfunc=np.sum,fill_value=0)
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\2725120943.py:8: FutureWarning: The provided callable <function sum at 0x0000021E7708A160> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   adidas_retailer_2021 = pd.pivot_table(adidas_2021,values='Total Sales',index=['Month'],columns='Retailer', aggfunc=np.sum,fill_value=0)

# %%
adidas_product_m=(data.groupby(["Product"])['Total Sales'].sum()/1000000).round(2).sort_values()

colors = ['blue', 'green', 'orange', 'red','purple','cyan','yellow']

plt.figure(figsize=(10, 6))
plt.barh(np.arange(len(adidas_product_m)), adidas_product_m.values, color=colors)

for i, (retailer, value) in enumerate(adidas_product_m.items()):
    plt.text(value, i, str(round(value, 2)), ha='left', va='center')

plt.title('Total Sales per Product')
plt.xlabel('Total Sales (Millions $)')
plt.ylabel('Retailer')

plt.yticks(np.arange(len(adidas_product_m)), adidas_product_m.keys())

plt.show()

# %%
adidas_product_retailer_k=(data.pivot_table(values='Total Sales',index='Retailer',columns='Product',aggfunc=np.mean)/1000).round(2)

plt.figure(figsize=(10, 6))
sns.heatmap(adidas_product_retailer_k, annot=True, fmt=".3f", cmap='inferno')

plt.title("Average Sales Performance for Different Products Across Various Retailers(Thousand)")
plt.xlabel("Product")
plt.ylabel("Retailer")
plt.xticks(rotation=45)
plt.yticks(rotation=45)

plt.show()
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\90866622.py:1: FutureWarning: The provided callable <function mean at 0x0000021E7708B240> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   adidas_product_retailer_k=(data.pivot_table(values='Total Sales',index='Retailer',columns='Product',aggfunc=np.mean)/1000).round(2)

# %%
from turtle import color


adidas_type_qunatity = data.groupby('Sales Method')['Units Sold'].sum()/1000

colors = ['yellow','red','orange']

ax = adidas_type_qunatity.plot(kind='bar',color=colors)

plt.xlabel('Sales Method')
plt.ylabel('Units Sold (in thousands)')
plt.title('Bar Chart: Units Sold by Sales Method')

# Adding value labels to the bars
for i, v in enumerate(adidas_type_qunatity):
    ax.text(i, v + 0.5, str(v), ha='center')

# Displaying the plot
plt.show()

# %%
adidas_type_sales =  (data.groupby('Sales Method')['Total Sales'].sum()/1000000).round(2)

colors = ['blue', 'cyan', 'violet']
ax = adidas_type_sales.plot(kind='bar', color=colors)

# Adding labels and title to the plot
plt.xlabel('Sales Method')
plt.ylabel('Units Sold (in milions)')
plt.title('Bar Chart: Total Sales by Sales Method')

# Adding value labels to the bars
for i, v in enumerate(adidas_type_sales):
    ax.text(i, v + 0.5, str(v), ha='center')

# Displaying the plot
plt.show()

# %%
adidas_product_sale=(data.pivot_table(values='Total Sales',index=['Product'],columns='Sales Method',aggfunc=np.sum)/1000000).round(2)
adidas_product_unit=(data.pivot_table(values='Units Sold',index=['Product'],columns='Sales Method',aggfunc=np.sum)/1000).round(2)

plt.figure(figsize=(8, 6))
sns.heatmap(adidas_product_sale, annot=True, fmt=".2f", cbar_kws={'label': 'Total Sales (Millions)'},cmap='viridis')
plt.title('Adidas Product Sales in Different Methods')
plt.xlabel('Sales Method')
plt.ylabel('Product')
plt.tight_layout()
plt.show()

# Create the heatmap for adidas_product_unit
plt.figure(figsize=(8, 6))
sns.heatmap(adidas_product_unit, annot=True, cmap="YlGnBu", fmt=".2f", cbar_kws={'label': 'Units Sold (Thousands)'})
plt.title('Adidas Amount of units in Different Methods')
plt.xlabel('Sales Method')
plt.ylabel('Product')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\2380578373.py:1: FutureWarning: The provided callable <function sum at 0x0000021E7708A160> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   adidas_product_sale=(data.pivot_table(values='Total Sales',index=['Product'],columns='Sales Method',aggfunc=np.sum)/1000000).round(2)
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_5836\2380578373.py:2: FutureWarning: The provided callable <function sum at 0x0000021E7708A160> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   adidas_product_unit=(data.pivot_table(values='Units Sold',index=['Product'],columns='Sales Method',aggfunc=np.sum)/1000).round(2)

# %%
sales_by_month = data.groupby(['Month','Year'])['Total Sales'].sum().sort_index(ascending=True).reset_index()
sales_by_month.index+=1
sales_by_month
# Out:
#         Month  Year  Total Sales
# 1       April  2020    3193081.0
# 2       April  2021    6498339.0
# 3      August  2020    2641630.0
# 4      August  2021    9651596.0
# 5    December  2020    1079202.0
# 6    December  2021   10336130.0
# 7    February  2020    2140813.0
# 8    February  2021    6123040.0
# 9     January  2020    2312746.0
# 10    January  2021    7432021.0
# 11       July  2020    2182388.0
# 12       July  2021   10368031.0
# 13       June  2020    1084194.0
# 14       June  2021    8718953.0
# 15      March  2020    2474202.0
# 16      March  2021    5220782.0
# 17        May  2020    2164764.0
# 18        May  2021    8576956.0
# 19   November  2020    1168050.0
# 20   November  2021    7855390.0
# 21    October  2020    1428569.0
# 22    October  2021    7110189.0
# 23  September  2020    2367686.0
# 24  September  2021    8037898.0

# %%
import plotly.express as px
line = data.groupby('Invoice Date')[['Total Sales','Operating Profit']].sum().reset_index()
line.index+=1
line
# Out:
#     Invoice Date  Total Sales  Operating Profit
# 1     2020-01-01     119516.0          56444.34
# 2     2020-01-02      97660.0          34247.16
# 3     2020-01-03      90323.0          30716.01
# 4     2020-01-04      88580.0          34848.02
# 5     2020-01-05     100329.0          34066.56
# ..           ...          ...               ...
# 720   2021-12-27      80353.0          40409.39
# 721   2021-12-28      40010.0          15009.10
# 722   2021-12-29      28859.0          12381.09
# 723   2021-12-30      22778.0           9123.03
# 724   2021-12-31      26534.0           9065.59
#
# [724 rows x 3 columns]

# %% [markdown]
# - Sales BY Invoice Date

# %%
fig = px.line(line, x="Invoice Date", y="Total Sales", title='Sales')
fig.show()

# %% [markdown]
# - Cities and Operating Cost

# %%
px.bar( grossing_cities, y= 'City', x = 'Operating Profit')
